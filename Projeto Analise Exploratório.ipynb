# %%
# Analise exploratória de Dados Da Cidade Nova york 2020
# Limpeza dos dados

# %%
# Import necessary modules
# Import da Bibliotecas 
import pandas as pd
import matplotlib.pyplot as plt
# %Matplotlib inline

# %%
df = pd.read_csv('DOB_Job_Application_Filings.csv')

# %%
df.head()
# Out:
#        Job #  Doc #    Borough House #           Street Name  Block     Lot  \
# 0  310085421    1.0   BROOKLYN     576       ST MARKS AVENUE   1224    20.0
# 1  122698090    1.0  MANHATTAN     555              BROADWAY    498    11.0
# 2  122750941    2.0  MANHATTAN     601      LEXINGTON AVENUE   1308  7501.0
# 3  302162424    1.0   BROOKLYN     505          HICKS STREET    321     9.0
# 4  421233025    2.0     QUEENS  105-20  ROCKAWAY BEACH BLVD.  16178    80.0
#
#        Bin # Job Type Job Status    ...     SPECIAL_ACTION_STATUS  \
# 0  3030873.0       A2          X    ...                         N
# 1  1007576.0       A2          X    ...                         N
# 2  1036474.0       A2          X    ...                         N
# 3  3003687.0       A1          R    ...                         N
# 4  4303820.0       A2          X    ...                         N
#
#   SPECIAL_ACTION_DATE BUILDING_CLASS  JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# ...

# %%
print(df.head())
# Out:
#        Job #  Doc #    Borough House #           Street Name  Block     Lot  \
# 0  310085421    1.0   BROOKLYN     576       ST MARKS AVENUE   1224    20.0
# 1  122698090    1.0  MANHATTAN     555              BROADWAY    498    11.0
# 2  122750941    2.0  MANHATTAN     601      LEXINGTON AVENUE   1308  7501.0
# 3  302162424    1.0   BROOKLYN     505          HICKS STREET    321     9.0
# 4  421233025    2.0     QUEENS  105-20  ROCKAWAY BEACH BLVD.  16178    80.0
#
#        Bin # Job Type Job Status    ...     SPECIAL_ACTION_STATUS  \
# 0  3030873.0       A2          X    ...                         N
# 1  1007576.0       A2          X    ...                         N
# 2  1036474.0       A2          X    ...                         N
# 3  3003687.0       A1          R    ...                         N
# 4  4303820.0       A2          X    ...                         N
#
#   SPECIAL_ACTION_DATE BUILDING_CLASS  JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# ...

# %%
print(df.tail())
# Out:
#                                  Job #  Doc #    Borough House # Street Name  \
# 245376                       120091097    1.0  MANHATTAN      20   PARK AVE{
# 245377                  "error" : true    NaN        NaN     NaN         NaN
# 245378    "message" : "Internal error"    NaN        NaN     NaN         NaN
# 245379                  "status" : 500    NaN        NaN     NaN         NaN
# 245380                               }    NaN        NaN     NaN         NaN
#
#        Block  Lot  Bin # Job Type Job Status   ...   SPECIAL_ACTION_STATUS  \
# 245376   NaN  NaN    NaN      NaN        NaN   ...                     NaN
# 245377   NaN  NaN    NaN      NaN        NaN   ...                     NaN
# 245378   NaN  NaN    NaN      NaN        NaN   ...                     NaN
# 245379   NaN  NaN    NaN      NaN        NaN   ...                     NaN
# 245380   NaN  NaN    NaN      NaN        NaN   ...                     NaN
#
# ...

# %%
print(df.shape)
# Out:
# (245381, 96)

# %%
# como deixar coluna em uma lista organizar
print(df.columns)
# Out:
# Index(['Job #', 'Doc #', 'Borough', 'House #', 'Street Name', 'Block', 'Lot',
#        'Bin #', 'Job Type', 'Job Status', 'Job Status Descrp',
#        'Latest Action Date', 'Building Type', 'Community - Board', 'Cluster',
#        'Landmarked', 'Adult Estab', 'Loft Board', 'City Owned', 'Little e',
#        'PC Filed', 'eFiling Filed', 'Plumbing', 'Mechanical', 'Boiler',
#        'Fuel Burning', 'Fuel Storage', 'Standpipe', 'Sprinkler', 'Fire Alarm',
#        'Equipment', 'Fire Suppression', 'Curb Cut', 'Other',
#        'Other Description', 'Applicant's First Name', 'Applicant's Last Name',
#        'Applicant Professional Title', 'Applicant License #',
#        'Professional Cert', 'Pre- Filing Date', 'Paid', 'Fully Paid',
#        'Assigned', 'Approved', 'Fully Permitted', 'Initial Cost',
#        'Total Est. Fee', 'Fee Status', 'Existing Zoning Sqft',
#        'Proposed Zoning Sqft', 'Horizontal Enlrgmt', 'Vertical Enlrgmt',
# ...

# %%
#Valores nulos 
#Values Unique
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245381 entries, 0 to 245380
# Data columns (total 96 columns):
# Job #                            245381 non-null object
# Doc #                            245377 non-null float64
# Borough                          245377 non-null object
# House #                          245371 non-null object
# Street Name                      245371 non-null object
# Block                            245240 non-null object
# Lot                              245240 non-null float64
# Bin #                            245376 non-null float64
# Job Type                         245376 non-null object
# Job Status                       245376 non-null object
# Job Status Descrp                245376 non-null object
# Latest Action Date               245376 non-null object
# Building Type                    245376 non-null object
# Community - Board                245017 non-null float64
# Cluster                          178491 non-null object
# ...

# %%
#Ver Tipos Das Colunas 
# column types
df.dtypes # Ver Ser variavel categorica , nominal
# Out:
# Job #                             object
# Doc #                            float64
# Borough                           object
# House #                           object
# Street Name                       object
# Block                             object
# Lot                              float64
# Bin #                            float64
# Job Type                          object
# Job Status                        object
# Job Status Descrp                 object
# Latest Action Date                object
# Building Type                     object
# Community - Board                float64
# Cluster                           object
# Landmarked                        object
# Adult Estab                       object
# Loft Board                        object
# City Owned                        object
# Little e                          object
# PC Filed                          object
# eFiling Filed                     object
# Plumbing                          object
# ...

# %%
df.drop('Doc #', axis= 1,inplace=True)

# %%
df.drop('Lot', axis= 1,inplace=True)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245381 entries, 0 to 245380
# Data columns (total 93 columns):
# Job #                            245381 non-null object
# Borough                          245377 non-null object
# House #                          245371 non-null object
# Street Name                      245371 non-null object
# Bin #                            245376 non-null float64
# Job Type                         245376 non-null object
# Job Status                       245376 non-null object
# Job Status Descrp                245376 non-null object
# Latest Action Date               245376 non-null object
# Building Type                    245376 non-null object
# Community - Board                245017 non-null float64
# Cluster                          178491 non-null object
# Landmarked                       231193 non-null object
# Adult Estab                      212134 non-null object
# Loft Board                       199927 non-null object
# ...

# %%
#Using to Quatile, Medin, 

df.describe()
# Out:
#                Doc #            Lot         Bin #  Community - Board  \
# count  245377.000000  245240.000000  2.453760e+05      245017.000000
# mean        1.189301     489.248226  2.272052e+06         221.600730
# std         0.596012    1796.642171  1.326105e+06         123.666977
# min         1.000000       0.000000  1.909000e+03           1.000000
# 25%         1.000000      12.000000  1.035776e+06         105.000000
# 50%         1.000000      30.000000  2.017766e+06         206.000000
# 75%         1.000000      55.000000  3.080180e+06         306.000000
# max        20.000000   99141.000000  5.868090e+06         595.000000
#
#        Existing Zoning Sqft  Proposed Zoning Sqft  Enlargement SQ Footage  \
# count          2.453760e+05          2.453760e+05           245376.000000
# mean           2.676391e+03          3.713596e+03              102.153943
# std            9.585902e+04          9.864399e+04             3539.864798
# ...

# %%
#  Print the value counts for 'Borough'
print(df['Borough'].value_counts(dropna=False))
# Print the value_counts for 'State'
print(df['State'].value_counts(dropna=False))

# Print the value counts for 'Site Fill'
print(df['Site Fill'].value_counts(dropna=False))# Valores de frequencia
# Out:
# MANHATTAN        115216
# BROOKLYN          74723
# QUEENS            24525
# BRONX             20653
# STATEN ISLAND     10260
# NaN                   4
# Name: Borough, dtype: int64
# NY     238468
# NJ       3936
# FL        415
# CA        357
# CT        356
# IL        251
# MA        179
# PA        178
# VA        166
# TX        138
# NC        107
# MD        100
# OH         92
# RI         90
# GA         65
# DC         53
# NV         42
# WA         36
# AZ         34
# UT         33
# TN         30
# CO         29
# KY         28
# SC         24
# MI         20
# MO         19
# IN         14
# ME         14
# MN         13
# NaN        13
# DE         12
# NM         11
# VT          9
# AR          7
# NH          7
# IA          5
# OK          5
# HI          4
# KS          4
# LA          3
# SD          3
# NE          2
# OR          2
# WI          2
# WY          2
# PR          1
# AL          1
# AK          1
# Name: State, dtype: int64
# ...

# %%
# Describe the column
print(df['Existing Zoning Sqft'].describe())
# Out:
# count    2.453760e+05
# mean     2.676391e+03
# std      9.585902e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.921476e+07
# Name: Existing Zoning Sqft, dtype: float64

# %%
# Plot the histogram
df['Existing Zoning Sqft'].plot(kind='hist', rot=70, logx=True, logy=True)
plt.show()
